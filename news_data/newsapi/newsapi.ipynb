# %%
import requests
import pandas as pd
from datetime import datetime, timedelta, timezone
import getpass
import json

# %%
# Base URL for News API
NEWSAPI_BASE_URL = 'https://newsapi.org/v2/everything'

# API Key from newsapi.org
newsapi_key = ['5ddc207db38548beb32baf54a71c680e', # N2N
               'fe81eb5f8465452ca563ecc0f39cdf9e', # V2S
               '260e896096e340069621dc89e664e4d7' # S2V
               #'994aa1fc07e74b39acf7df2a61ec6df1'  # N53
              ]

# NEWSAPI Usage
query_string = 'US Presidential Elections OR 2024 Elections OR Election Results OR Democrat OR Republican'

# Global variables
all_articles = []
data_rows = []
run_id = 'UNDEFINED'

# Output Files
articles_csv = "news_data/filtered_news_data.csv"  # Specify the file path
rundata_csv = "news_data/run_data.csv"


articles_columns = ['run_id', 'api_key', 'start_time', 'end_time', 'Total_articles', 'Filtered_articles']
rundata_columns = ["API","Source", "Title", "PublishedAt", "Url"]

# %%
# Function to get news data
def get_news(api_key=None, country='us', category=None, query=None, from_time=None, to_time=None, page_size=10):
    # Define parameters
    params = {
        'apiKey': api_key,
        'from': from_time,              # Start date for the articles
        'to': to_time,                # End date for the articles
        'q': query,            # Optional: keyword or phrase to search for
        'pageSize': page_size, # Number of articles to return
        'searchIn': "title,content,description",
        'sortBy': 'popularity',
        'pageSize': 100,
        'language': 'en',
        #'country': country,    # Country code (e.g., 'us' for the United States)
        #'category': category,  # Optional: e.g., 'technology', 'sports'
        #'from': "2024-10-21",              # Start date for the articles
        #'to': "2024-10-21",                # End date for the articles

    }

    # Send GET request to the API
    response = requests.get(NEWSAPI_BASE_URL, params=params)

    #if response.status_code == 200:
    #    articles = response.json().get("articles", [])
    #    for article in articles:
    #        print(f"Title: {article['title']}")
    #        print(f"Source: {article['source']['name']}")
    #        print(f"Published At: {article['publishedAt']}")
    #        print(f"URL: {article['url']}")
    #        print("-" * 80)
    #else:
    #    print(f"Failed to retrieve data: {response.status_code}, {response.text}")
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse JSON response
        news_data = response.json()
        return news_data['articles']
    else:
        print("Failed to retrieve data:", response.status_code, response.text)
        return None

# %%
def create_newsDf_newsapi(articles):
    filtered_data = []
    
    for item in articles:
        title_removed = item.get('title') == '[Removed]'
        source_removed = item.get('source', {}).get('name') == '[Removed]'
        url_videos = 'videos' in item.get('url', '')

        if not ((title_removed and source_removed) or url_videos):
            filtered_data.append({
                'API': 'newsapi',  # Fixed value
                'source': item.get('source', {}).get('name'),
                'title': item.get('title'),
                'publishedAt': item.get('publishedAt'),
                'url': item.get('url')
            })
    return pd.DataFrame(filtered_data)

# %%
def print_news(article):
    print(f"Keys: {article[0].keys()}")
    
    for idx, article in enumerate(articles, start=1):
        print(f"{idx}. Title: {article['title']}")
        print(f"   Source: {article['source']['name']}")
        #print(f"   Description: {article['description']}")
        print(f"   Published At: {article['publishedAt']}")
        print(f"   URL: {article['url']}")
        print("-" * 80)

# %%
def write_to_csv(df, file_path, head):
    df.to_csv(file_path, index=False, mode='a', header=False)
    print(f"Data written to {file_path}")

# %%
def create_runDf_data(api_key, articles, newsDf, start_time, end_time):
    run_data = []

    # Data for this iteration
    length_of_fetched_articles = len(articles)
    length_of_filtered_articles = newsDf.shape[0]

    all_articles.extend(articles)
    
    # Append a row for the DataFrame
    run_data.append({
        "run_id": run_id,
        "api_key": api_key,
        "start_time": start_time,
        "end_time": end_time,
        "Total_articles": length_of_fetched_articles,
        "Filtered_articles": length_of_filtered_articles,
    })

    return pd.DataFrame(run_data)

# %%
def generate_run_id():
    username = getpass.getuser()
    timestamp = datetime.now().strftime('%Y%m%d%H%M')
    run_id = "{}_{}".format(username, timestamp)
    print("\n\033[94mRun ID: {}\033[0m\n".format(run_id))
    return run_id

# %%
def generate_time_blocks(start_time, end_time):
    """
    Generate 6-hour time blocks between start_time and end_time.

    Args:
        start_time (datetime): The start datetime.
        end_time (datetime): The end datetime.

    Returns:
        list: A list of dictionaries containing 'from' and 'to' for each time block.
    """
    time_blocks = []
    current_time = start_time

    while current_time <= end_time:
        # Divide each day into 6-hour blocks
        for start_hour in range(0, 24, 6):
            block_start = datetime(current_time.year, current_time.month, current_time.day, start_hour, 0, 0)
            block_end = block_start + timedelta(hours=6) - timedelta(seconds=1)

            # Ensure block_end does not exceed end_time
            if block_start > end_time:
                break

            time_blocks.append({
                'from': block_start.strftime("%Y-%m-%dT%H:%M:%S"),
                'to': block_end.strftime("%Y-%m-%dT%H:%M:%S")
            })

        # Move to the next day
        current_time += timedelta(days=1)

    return time_blocks

# %%
#Generate Run ID
run_id = generate_run_id()

# Define the start and end times
start_time = datetime.utcnow() - timedelta(days=30)
#end_time = datetime.utcnow() - timedelta(days=29)
end_time = datetime.utcnow()

# Call the function
time_blocks = generate_time_blocks(start_time, end_time)

request_count = 0
#newsDf = pd.DataFrame()

# Print the time blocks
for block in time_blocks:
    request_count += 1
    #api_key = (lambda count: newsapi_key[(count // 2) % len(newsapi_key)])(int(request_count))
    api_key = (lambda count: newsapi_key[(count // 40) % len(newsapi_key)])(int(request_count))
    print(f"count: {request_count} api_key: {api_key}")
    
    articles = get_news(api_key,
                        query = query_string, 
                        category='general', 
                        from_time=block['from'],
                        to_time=block['to'],
                        page_size=10)
    
    newsDf = create_newsDf_newsapi(articles)
    write_to_csv(newsDf, articles_csv, articles_columns)

    #if articles:
    #   print_news(articles)

    runDf = create_runDf_data(api_key, articles, newsDf, block['from'], block['to'])
    write_to_csv(runDf, rundata_csv, rundata_columns)

# Save all articles to a JSON file
with open(f"news_data/{run_id}.json", "w") as json_file:
    json.dump(all_articles, json_file, indent=4)
# Out:
# Run ID: nirmv_202411211653
#
# count: 1 api_key: 5ddc207db38548beb32baf54a71c680e
# /var/folders/xx/4wqdx8h939s29ryq_zympn8c0000gn/T/ipykernel_8675/2368396823.py:5: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start_time = datetime.utcnow() - timedelta(days=30)
# /var/folders/xx/4wqdx8h939s29ryq_zympn8c0000gn/T/ipykernel_8675/2368396823.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   end_time = datetime.utcnow()
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 2 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 3 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 4 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 5 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 6 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 7 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 8 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 9 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 10 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 11 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 12 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 13 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 14 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 15 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 16 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 17 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 18 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 19 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 20 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 21 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 22 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 23 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 24 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 25 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 26 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 27 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 28 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 29 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 30 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 31 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 32 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 33 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 34 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 35 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 36 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 37 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 38 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 39 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 40 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 41 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 42 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 43 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 44 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 45 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 46 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 47 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 48 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 49 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 50 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 51 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 52 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 53 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 54 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 55 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 56 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 57 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 58 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 59 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 60 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 61 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 62 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 63 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 64 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 65 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 66 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 67 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 68 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 69 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 70 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 71 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 72 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 73 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 74 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 75 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 76 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 77 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 78 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 79 api_key: fe81eb5f8465452ca563ecc0f39cdf9e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 80 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 81 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 82 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 83 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 84 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 85 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 86 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 87 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 88 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 89 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 90 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 91 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 92 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 93 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 94 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 95 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 96 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 97 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 98 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 99 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 100 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 101 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 102 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 103 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 104 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 105 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 106 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 107 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 108 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 109 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 110 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 111 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 112 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 113 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 114 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 115 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 116 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 117 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 118 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 119 api_key: 260e896096e340069621dc89e664e4d7
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 120 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 121 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
# count: 122 api_key: 5ddc207db38548beb32baf54a71c680e
# Data written to news_data/filtered_news_data.csv
# Data written to news_data/run_data.csv
